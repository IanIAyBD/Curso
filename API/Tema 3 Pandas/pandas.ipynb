# %% [markdown]
# # PANDAS

# %% [markdown]
# ### Crear una serie:

# %%
import pandas as pd

# %%
estudiantes = pd.Series(data=['Luis', 'Francia', 40], index=['nombre', 'pais', 'edad'])

# %%
estudiantes
# Out:
# nombre       Luis
# pais      Francia
# edad           40
# dtype: object

# %%
print(estudiantes.shape)
# Out:
# (3,)

# %%
print(estudiantes.ndim)
# Out:
# 1

# %%
print(estudiantes.size)
# Out:
# 3

# %%
print(estudiantes.values)
# Out:
# ['Luis' 'Francia' 40]

# %%
print(estudiantes.index)
# Out:
# Index(['nombre', 'pais', 'edad'], dtype='object')

# %%
print(estudiantes[[0,1]])
# Out:
# nombre       Luis
# pais      Francia
# dtype: object

# %%
print(estudiantes.loc['pais'])
# Out:
# Francia

# %%
print(estudiantes.iloc[2])
# Out:
# 40

# %%
estudiantes.drop(['edad'])
# Out:
# nombre       Luis
# pais      Francia
# dtype: object

# %%
estudiantes
# Out:
# nombre       Luis
# pais      Francia
# edad           40
# dtype: object

# %%
estudiantes.drop(['edad'], inplace=True)

# %%
estudiantes
# Out:
# nombre       Luis
# pais      Francia
# dtype: object

# %% [markdown]
# #### Operaciones aritméticas con Series:

# %%
fruits = pd.Series(data = [20, 40, 60], index = ['mango', 'manzana', 'platano'])

# %%
fruits
# Out:
# mango      20
# manzana    40
# platano    60
# dtype: int64

# %%
print(fruits + 3)
# Out:
# mango      23
# manzana    43
# platano    63
# dtype: int64

# %%
fruits
# Out:
# mango      20
# manzana    40
# platano    60
# dtype: int64

# %%
import numpy as np
print(np.power(fruits,2))
# Out:
# mango       400
# manzana    1600
# platano    3600
# dtype: int64

# %%
print(fruits[['platano','manzana']] * 10)
# Out:
# platano    600
# manzana    400
# dtype: int64

# %%
fruits
# Out:
# mango      20
# manzana    40
# platano    60
# dtype: int64

# %% [markdown]
# ### Crear DataFrames:

# %% [markdown]
# Objeto de dos dimensiones con filas y columnas etiquetadas. Cada fila y cada columna tienen un nombre.

# %%
items = {'Pepe': pd.Series([10, 20, 30], ['manzana', 'platano', 'mango']),
		'Ana': pd.Series([40, 50, 60], ['manzana', 'naranja', 'mango'])}

# %%
df = pd.DataFrame(items)

# %%
df
# Out:
#          Pepe   Ana
# mango    30.0  60.0
# manzana  10.0  40.0
# naranja   NaN  50.0
# platano  20.0   NaN

# %%
#podría crear el DataFrame también sólo con la columna o los índices que quiero:
df = pd.DataFrame(items, columns = ['Pepe'], index = ['manzana', 'platano'])

# %%
df
# Out:
#          Pepe
# manzana    10
# platano    20

# %%
#OTRO EJEMPLO:
df = pd.DataFrame({
    'temperatura':[35.5,36.7,22.3,39.7],
    'presion':[3.6,2.4,5.5,5.5]
},index=['3h','6h','9h','12h'])

# %%
df
# Out:
#      temperatura  presion
# 3h          35.5      3.6
# 6h          36.7      2.4
# 9h          22.3      5.5
# 12h         39.7      5.5

# %%
#Añadir una nueva columna al inicio del DataFrame:
df.insert(0,"humedad",[65,63,65,67])

# %%
df
# Out:
#      humedad  temperatura  presion
# 3h        65         35.5      3.6
# 6h        63         36.7      2.4
# 9h        65         22.3      5.5
# 12h       67         39.7      5.5

# %%
df=pd.DataFrame(
    [[35.5,3.6], [36.7, 2.4], [22.3, 5.5], [39.7, 5.5]],
columns=['temperatura', 'presion'],
index=['3h','6h','9h','12h'])

# %%
#Añadir una nueva columna, después de la columna "presion" ya que es la 2º del DataFrame
df.insert(2,"humedad",[65,63,65,67])

# %%
df
# Out:
#      temperatura  presion  humedad
# 3h          35.5      3.6       65
# 6h          36.7      2.4       63
# 9h          22.3      5.5       65
# 12h         39.7      5.5       67

# %%
df2=pd.read_csv("datos.txt",sep=",")

# %%
df2
# Out:
#    temperatura  presion  humedad
# 0         35.5      3.6       65
# 1         36.7      2.4       63
# 2         22.3      5.5       65
# 3         39.7      5.5       67

# %% [markdown]
# #### IMPORTAR "data_fifa.csv" de un ejercicio en **Kaggle**:

# %%
df = pd.read_csv('data_fifa.csv')

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
#Mostrar tabla con datos:
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.tail(2)
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 18205       18205  246268  D. Walker-Rice   17
# 18206       18206  246269       G. Nugent   16
#
#                                                 Photo Nationality  \
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 18205  Tranmere Rovers  ...      46.0    20.0           25.0           27.0
# 18206  Tranmere Rovers  ...      43.0    40.0           43.0           50.0
#
#       GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 18205     14.0         6.0       14.0            8.0        9.0          €143K
# ...

# %%
#Mostrar las variables estadísticas más importantes de un datasets
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
df.max(numeric_only=True)
# Out:
# Unnamed: 0                   18206.0
# ID                          246620.0
# Age                             45.0
# Overall                         94.0
# Potential                       95.0
# Special                       2346.0
# International Reputation         5.0
# Weak Foot                        5.0
# Skill Moves                      5.0
# Jersey Number                   99.0
# Crossing                        93.0
# Finishing                       95.0
# HeadingAccuracy                 94.0
# ShortPassing                    93.0
# Volleys                         90.0
# Dribbling                       97.0
# Curve                           94.0
# FKAccuracy                      94.0
# LongPassing                     93.0
# BallControl                     96.0
# Acceleration                    97.0
# SprintSpeed                     96.0
# Agility                         96.0
# Reactions                       96.0
# Balance                         96.0
# ...

# %%
df.corr()
# Out:
#                           Unnamed: 0        ID       Age   Overall  Potential  \
# Unnamed: 0                  1.000000  0.415757 -0.454846 -0.972791  -0.633395
# ID                          0.415757  1.000000 -0.739208 -0.417025   0.047074
# Age                        -0.454846 -0.739208  1.000000  0.452350  -0.253312
# Overall                    -0.972791 -0.417025  0.452350  1.000000   0.660939
# Potential                  -0.633395  0.047074 -0.253312  0.660939   1.000000
# Special                    -0.596508 -0.231352  0.236695  0.606960   0.383727
# International Reputation   -0.413322 -0.356191  0.253765  0.499491   0.372993
# Weak Foot                  -0.204026 -0.075784  0.059867  0.212015   0.162346
# Skill Moves                -0.415672 -0.056914  0.027649  0.414463   0.354290
# Jersey Number               0.213645  0.182074 -0.241156 -0.218931  -0.010474
# Crossing                   -0.390062 -0.131994  0.130545  0.394972   0.246319
# ...

# %% [markdown]
# ### Acceder a los datos:

# %%
df=pd.DataFrame(
    [[35.5,3.6,65], [36.7, 2.4,63], [22.3, 5.5,65], [39.7, 5.5,67]],
columns=['temperatura', 'presion', 'humedad'],
index=['3h','6h','9h','12h'])

# %%
df
# Out:
#      temperatura  presion  humedad
# 3h          35.5      3.6       65
# 6h          36.7      2.4       63
# 9h          22.3      5.5       65
# 12h         39.7      5.5       67

# %% [markdown]
# ### iloc:

# %%
df.iloc[0,1]
# Out:
# 3.6

# %%
df.iloc[0]
# Out:
# temperatura    35.5
# presion         3.6
# humedad        65.0
# Name: 3h, dtype: float64

# %%
df.iloc[:,2]
# Out:
# 3h     65
# 6h     63
# 9h     65
# 12h    67
# Name: humedad, dtype: int64

# %% [markdown]
# ### loc:

# %%
df
# Out:
#      temperatura  presion  humedad
# 3h          35.5      3.6       65
# 6h          36.7      2.4       63
# 9h          22.3      5.5       65
# 12h         39.7      5.5       67

# %%
df.loc['3h','temperatura']
# Out:
# 35.5

# %%
df.loc['3h']
# Out:
# temperatura    35.5
# presion         3.6
# humedad        65.0
# Name: 3h, dtype: float64

# %%
df.loc[:,'temperatura']
# Out:
# 3h     35.5
# 6h     36.7
# 9h     22.3
# 12h    39.7
# Name: temperatura, dtype: float64

# %%
df['temperatura']
# Out:
# 3h     35.5
# 6h     36.7
# 9h     22.3
# 12h    39.7
# Name: temperatura, dtype: float64

# %%
df.loc[:,'temperatura'][0]
# Out:
# 35.5

# %%
df.iloc[:,1]['3h']
# Out:
# 3.6

# %%
df.loc['3h'][1]
# Out:
# 3.6

# %%
df.iloc[0]['temperatura']
# Out:
# 35.5

# %% [markdown]
# ### Nombres de las etiquetas:

# %%
df.index
# Out:
# Index(['3h', '6h', '9h', '12h'], dtype='object')

# %% [markdown]
# ### Nombres de las columnas:

# %%
df.columns
# Out:
# Index(['temperatura', 'presion', 'humedad'], dtype='object')

# %% [markdown]
# ### Valores del DATAFRAME:

# %%
df.values
# Out:
# array([[35.5,  3.6, 65. ],
#        [36.7,  2.4, 63. ],
#        [22.3,  5.5, 65. ],
#        [39.7,  5.5, 67. ]])

# %%
#valores nulos de cada columna
df.isnull().sum()
# Out:
# temperatura    0
# presion        0
# humedad        0
# dtype: int64

# %%
df.dtypes
# Out:
# temperatura    float64
# presion        float64
# humedad          int64
# dtype: object

# %%
#características del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 3h to 12h
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperatura  4 non-null      float64
#  1   presion      4 non-null      float64
#  2   humedad      4 non-null      int64
# dtypes: float64(2), int64(1)
# memory usage: 300.0+ bytes

# %%
df.shape
# Out:
# (4, 3)

# %%
df
# Out:
#      temperatura  presion  humedad
# 3h          35.5      3.6       65
# 6h          36.7      2.4       63
# 9h          22.3      5.5       65
# 12h         39.7      5.5       67

# %%
#Cuántos valores hay distintos
df.groupby('presion').size()
# Out:
# presion
# 2.4    1
# 3.6    1
# 5.5    2
# dtype: int64

# %%
#Una consulta "query"
df.query('temperatura>36 and presion<3.0')
# Out:
#     temperatura  presion  humedad
# 6h         36.7      2.4       63

# %%
df.eval('temperatura*humedad')
# Out:
# 3h     2307.5
# 6h     2312.1
# 9h     1449.5
# 12h    2659.9
# dtype: float64

# %%
df
# Out:
#      temperatura  presion  humedad
# 3h          35.5      3.6       65
# 6h          36.7      2.4       63
# 9h          22.3      5.5       65
# 12h         39.7      5.5       67

# %% [markdown]
# ### Volviendo al DATAFRAME del FIFA:

# %%
df = pd.read_csv('data_fifa.csv')

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# ...

# %% [markdown]
# ### 3 PREGUNTAS:

# %% [markdown]
# #### ¿Cuántos jugadores están en el FC Barcelona?

# %%
df[df.Club == "FC Barcelona"].count()
# Out:
# Unnamed: 0        33
# ID                33
# Name              33
# Age               33
# Photo             33
#                   ..
# GKHandling        33
# GKKicking         33
# GKPositioning     33
# GKReflexes        33
# Release Clause    33
# Length: 89, dtype: int64

# %% [markdown]
# ##### <<Solución>> (33)

# %%
df[df['Club'] == 'FC Barcelona']
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 0               0  158023         L. Messi   31
# 7               7  176580        L. Suárez   31
# 18             18  192448    M. ter Stegen   26
# 20             20  189511  Sergio Busquets   29
# 32             32  189242         Coutinho   26
# 42             42  205600        S. Umtiti   24
# 49             49  189332       Jordi Alba   29
# 53             53  168651       I. Rakitić   30
# 54             54  152729            Piqué   31
# 96             96  181872         A. Vidal   31
# 155           155  231443       O. Dembélé   21
# 192           192  199564    Sergi Roberto   26
# 228           228  230658           Arthur   21
# 236           236  222737           Malcom   21
# 239           239  220440       C. Lenglet   23
# 263           263  201400          Rafinha   25
# 266           266  199987     J. Cillessen   29
# 324           324  227928    Nélson Semedo   24
# ...

# %% [markdown]
# #### ¿Cuántos jugadores son de España?

# %%
df[df.Nationality == "Spain"].count()
# Out:
# Unnamed: 0        1072
# ID                1072
# Name              1072
# Age               1072
# Photo             1072
#                   ...
# GKHandling        1071
# GKKicking         1071
# GKPositioning     1071
# GKReflexes        1071
# Release Clause     974
# Length: 89, dtype: int64

# %% [markdown]
# ##### <<Solución>> (1072)

# %%
df[df['Nationality'] == 'Spain']
# Out:
#        Unnamed: 0      ID                 Name  Age  \
# 3               3  193080               De Gea   27
# 8               8  155862         Sergio Ramos   32
# 13             13  168542          David Silva   32
# 20             20  189511      Sergio Busquets   29
# 30             30  197781                 Isco   26
# ...           ...     ...                  ...  ...
# 17043       17043  220190        Cristian Arco   23
# 17070       17070  244016               Taliby   21
# 17116       17116  245597         Víctor Gómez   18
# 17274       17274  243194            Hugo Díaz   21
# 17926       17926  244559  Carlos Mendes Gomes   19
#
#                                                 Photo Nationality  \
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 8      https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 13     https://cdn.sofifa.org/players/4/19/168542.png       Spain
# 20     https://cdn.sofifa.org/players/4/19/189511.png       Spain
# ...

# %% [markdown]
# #### ¿Cuál es la puntuación máxima que se le da en FIFA?   (Overall)

# %%
df[df["Overall"] == df["Overall"].max()]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0      6.0        11.0
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
# 1       15.0           14.0       11.0        €127.1M
#
# ...

# %% [markdown]
# ##### <<Solución>> (94. Son 2, Messi y Ronaldo)

# %%
df[df['Overall'] == df['Overall'].max()]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0      6.0        11.0
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
# 1       15.0           14.0       11.0        €127.1M
#
# ...

# %% [markdown]
# ### Cambiar la estructura (**melt**):

# %%
df= pd.read_csv("notas.txt",sep=",")

# %%
df
# Out:
#     alumno asignatura  eval1  eval2  eval3  final
# 0      Ana       Soci      4      7      7      6
# 1      Ana       Natu      5      7      8      7
# 2      Ana     Plasti      8      8      7      8
# 3      Ana     Física      8      9      9      9
# 4      Ana      Caste      7      7      6      7
# 5      Ana       Mate      5      5      6      5
# 6      Ana     Inglés      7      5      6      6
# 7      Ana      Valen      6      6      5      6
# 8      Ana    Valores      9      9      9      9
# 9   Sergio       Soci      5      8      6      6
# 10  Sergio       Natu      6      8      7      7
# 11  Sergio     Plasti      6      6      6      6
# 12  Sergio     Física      8      9      8      8
# 13  Sergio      Caste      7      7      7      7
# 14  Sergio       Mate      5      6      5      5
# 15  Sergio     Inglés      7      6      5      6
# 16  Sergio      Valen      6      5      5      5
# 17  Sergio    Valores      9      9      9      9

# %%
datos = df.melt(id_vars = ["alumno", "asignatura"], var_name = "eval", value_name = 'nota')

# %%
datos
# Out:
#     alumno asignatura   eval  nota
# 0      Ana       Soci  eval1     4
# 1      Ana       Natu  eval1     5
# 2      Ana     Plasti  eval1     8
# 3      Ana     Física  eval1     8
# 4      Ana      Caste  eval1     7
# ..     ...        ...    ...   ...
# 67  Sergio      Caste  final     7
# 68  Sergio       Mate  final     5
# 69  Sergio     Inglés  final     6
# 70  Sergio      Valen  final     5
# 71  Sergio    Valores  final     9
#
# [72 rows x 4 columns]

# %% [markdown]
# ### Asimetría de los datos (**skew**):

# %%
df=pd.DataFrame(
    [[35.5,3.6,65], [36.7, 2.4,63], [22.3, 5.5,65], [39.7, 5.5,67]],
columns=['temperatura', 'presion', 'humedad'],
index=['3h','6h','9h','12h'])

# %%
df
# Out:
#      temperatura  presion  humedad
# 3h          35.5      3.6       65
# 6h          36.7      2.4       63
# 9h          22.3      5.5       65
# 12h         39.7      5.5       67

# %%
df.skew()
# Out:
# temperatura   -1.679645
# presion       -0.508283
# humedad        0.000000
# dtype: float64

# %%
#OTRO EJEMPLO MÁS AMPLIO:
df = pd.read_csv("nba.csv")
df
df.skew(numeric_only=True, axis = 0, skipna = True)
# Out:
# Number    1.668386
# Age       0.626349
# Weight    0.113788
# Salary    1.576321
# dtype: float64

# %%
df.skew(numeric_only=True, axis = 1, skipna = True)
# Out:
# 0      2.000000
# 1      2.000000
# 2      1.730362
# 3      2.000000
# 4      2.000000
#          ...
# 453    2.000000
# 454    2.000000
# 455    2.000000
# 456    2.000000
# 457         NaN
# Length: 458, dtype: float64

# %% [markdown]
# ### GRAFICAS:

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Number'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %%
df=pd.DataFrame(
    [[35.5,3.6,65], [36.7, 2.4,63], [22.3, 5.5,65], [39.7, 5.5,67]],
columns=['temperatura', 'presion', 'humedad'],
index=['3h','6h','9h','12h'])

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'temperatura'}>,
#         <AxesSubplot:title={'center':'presion'}>],
#        [<AxesSubplot:title={'center':'humedad'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.plot(kind = 'density', 
          subplots = True,  
          layout = (3,3),
          figsize=(10,10),
          sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/INFORMATICA/alu10181909/Escriptori/github/Curso/API/Tema 3 Pandas/pandas.ipynb Cell 115' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/INFORMATICA/alu10181909/Escriptori/github/Curso/API/Tema%203%20Pandas/pandas.ipynb#ch0000114?line=0'>1</a> from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
reporte = ProfileReport(df, title = "Mi reporte")

# %%
reporte.to_file("reporte.html")
